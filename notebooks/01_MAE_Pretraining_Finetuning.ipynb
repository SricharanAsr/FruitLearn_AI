# %% [markdown]
# # FruitLearn AI: Masked Autoencoders (MAE) Self-Supervised Learning
# **Author:** Sricharan A (Member 3 - MAE & ResNet-18 Baseline Lead)
#
# This notebook implements Self-Supervised Pre-training of Vision Transformers (ViT-Base) using Masked Autoencoders (MAE) with a 75% random masking ratio, followed by supervised downstream classification fine-tuning.

# %%
import torch
from src.train_mae import MaskedAutoencoderViT
from src.dataset import load_fruit_dataset

print(f"PyTorch Version: {torch.__version__}")
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Device: {device}")

# %%
# Initialize MAE Model with 75% Masking Ratio
mae_model = MaskedAutoencoderViT(mask_ratio=0.75).to(device)
print(f"Total Model Parameters: {sum(p.numel() for p in mae_model.parameters()):,}")
