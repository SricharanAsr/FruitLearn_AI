# %% [markdown]
# # FruitLearn AI: ResNet-18 Supervised Baseline Training
# **Author:** Sricharan A (Member 3 - MAE & ResNet-18 Baseline Lead)
#
# This notebook trains a baseline standard supervised Convolutional Neural Network (ResNet-18) on the FruitLearn AI dataset to serve as an empirical benchmark against self-supervised MAE representations.

# %%
import torch
from src.train_baseline import build_resnet18_baseline

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
baseline_model = build_resnet18_baseline(num_classes=6, pretrained=True).to(device)
print(f"ResNet-18 Baseline initialized. Parameters: {sum(p.numel() for p in baseline_model.parameters()):,}")
